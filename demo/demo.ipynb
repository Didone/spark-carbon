# %%
spark.read.format("parquet").load("s3://dora.data.la/raw/sample.parquet").show()
# Out:
# +---+-----+---+--------+----+-----+-------+-------+-----+-------+-----+---+----+------+
# |age|  sex| cp|trestbps|chol|  fbs|restecg|thalach|exang|oldpeak|slope| ca|thal|target|
# +---+-----+---+--------+----+-----+-------+-------+-----+-------+-----+---+----+------+
# | 37| true|  2|     130| 250|false|   true|    187|false|    3.5|    0|  0|   2|  true|
# | 39| true|  2|     140| 321|false|  false|    182|false|    0.0|    2|  0|   2|  true|
# | 34| true|  3|     118| 182|false|  false|    174|false|    0.0|    2|  0|   2|  true|
# | 35|false|  0|     138| 183|false|   true|    182|false|    1.4|    2|  0|   2|  true|
# | 29| true|  1|     130| 204|false|  false|    202|false|    0.0|    2|  0|   2|  true|
# | 37|false|  2|     120| 215|false|   true|    170|false|    0.0|    2|  0|   2|  true|
# | 39|false|  2|      94| 199|false|   true|    179|false|    0.0|    2|  0|   2|  true|
# | 34|false|  1|     118| 210|false|   true|    192|false|    0.7|    2|  0|   2|  true|
# ...

# %%
spark.read.format("carbon").load("s3://dora.data.la/warehouse/carbon_table/").toPandas()
# Out:
#     age    sex  cp  trestbps  chol    fbs  restecg  thalach  exang  oldpeak  \
# 0    37   True   2       130   250  False     True      187  False      3.5
# 1    39   True   2       140   321  False    False      182  False      0.0
# 2    34   True   3       118   182  False    False      174  False      0.0
# 3    35  False   0       138   183  False     True      182  False      1.4
# 4    29   True   1       130   204  False    False      202  False      0.0
# 5    37  False   2       120   215  False     True      170  False      0.0
# 6    39  False   2        94   199  False     True      179  False      0.0
# 7    34  False   1       118   210  False     True      192  False      0.7
# 8    39  False   2       138   220  False     True      152  False      0.0
# 9    35   True   1       122   192  False     True      174  False      0.0
# 10   38   True   2       138   175  False     True      173  False      0.0
# ...
